# %% [markdown]
# #Setup

# %%
# !pip install apache-beam
# Out:
# Collecting apache-beam
#   Downloading apache_beam-2.61.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.4 kB)
# Collecting crcmod<2.0,>=1.7 (from apache-beam)
#   Downloading crcmod-1.7.tar.gz (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.7/89.7 kB 6.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: orjson<4,>=3.9.7 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (3.10.12)
# Collecting dill<0.3.2,>=0.3.1.1 (from apache-beam)
#   Downloading dill-0.3.1.1.tar.gz (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.0/152.0 kB 8.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting cloudpickle~=2.2.1 (from apache-beam)
#   Downloading cloudpickle-2.2.1-py3-none-any.whl.metadata (6.9 kB)
# Collecting fastavro<2,>=0.23.6 (from apache-beam)
#   Downloading fastavro-1.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.5 kB)
# Collecting fasteners<1.0,>=0.3 (from apache-beam)
#   Downloading fasteners-0.19-py3-none-any.whl.metadata (4.9 kB)
# Collecting grpcio!=1.48.0,!=1.59.*,!=1.60.*,!=1.61.*,!=1.62.0,!=1.62.1,<1.66.0,<2,>=1.33.1 (from apache-beam)
#   Downloading grpcio-1.65.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.3 kB)
# Collecting hdfs<3.0.0,>=2.1.0 (from apache-beam)
#   Downloading hdfs-2.7.3.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.5/43.5 kB 3.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: httplib2<0.23.0,>=0.8 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (0.22.0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (4.23.0)
# Collecting jsonpickle<4.0.0,>=3.0.0 (from apache-beam)
#   Downloading jsonpickle-3.4.2-py3-none-any.whl.metadata (8.1 kB)
# Requirement already satisfied: numpy<2.2.0,>=1.14.3 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (1.26.4)
# Collecting objsize<0.8.0,>=0.6.1 (from apache-beam)
#   Downloading objsize-0.7.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: packaging>=22.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (24.2)
# Collecting pymongo<5.0.0,>=3.8.0 (from apache-beam)
#   Downloading pymongo-4.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Requirement already satisfied: proto-plus<2,>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (1.25.0)
# Requirement already satisfied: protobuf!=4.0.*,!=4.21.*,!=4.22.0,!=4.23.*,!=4.24.*,<6.0.0.dev0,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (4.25.5)
# Collecting pydot<2,>=1.2.0 (from apache-beam)
#   Downloading pydot-1.4.2-py2.py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: python-dateutil<3,>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (2.8.2)
# Requirement already satisfied: pytz>=2018.3 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (2024.2)
# Collecting redis<6,>=5.0.0 (from apache-beam)
#   Downloading redis-5.2.1-py3-none-any.whl.metadata (9.1 kB)
# Requirement already satisfied: regex>=2020.6.8 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (2024.11.6)
# Requirement already satisfied: requests<3.0.0,>=2.24.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (2.32.3)
# Collecting sortedcontainers>=2.4.0 (from apache-beam)
#   Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: typing-extensions>=3.7.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (4.12.2)
# Collecting zstandard<1,>=0.18.0 (from apache-beam)
#   Downloading zstandard-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: pyyaml<7.0.0,>=3.12 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (6.0.2)
# Collecting pyarrow<17.0.0,>=3.0.0 (from apache-beam)
#   Downloading pyarrow-16.1.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.0 kB)
# Collecting pyarrow-hotfix<1 (from apache-beam)
#   Downloading pyarrow_hotfix-0.6-py3-none-any.whl.metadata (3.6 kB)
# Collecting docopt (from hdfs<3.0.0,>=2.1.0->apache-beam)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from hdfs<3.0.0,>=2.1.0->apache-beam) (1.17.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from httplib2<0.23.0,>=0.8->apache-beam) (3.2.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam) (0.22.3)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo<5.0.0,>=3.8.0->apache-beam)
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: async-timeout>=4.0.3 in /usr/local/lib/python3.10/dist-packages (from redis<6,>=5.0.0->apache-beam) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam) (2024.12.14)
# Downloading apache_beam-2.61.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (15.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.8/15.8 MB 86.3 MB/s eta 0:00:00
# Downloading cloudpickle-2.2.1-py3-none-any.whl (25 kB)
# Downloading fastavro-1.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 68.8 MB/s eta 0:00:00
# Downloading fasteners-0.19-py3-none-any.whl (18 kB)
# Downloading grpcio-1.65.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 77.1 MB/s eta 0:00:00
# Downloading jsonpickle-3.4.2-py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.3/46.3 kB 3.1 MB/s eta 0:00:00
# Downloading objsize-0.7.0-py3-none-any.whl (11 kB)
# Downloading pyarrow-16.1.0-cp310-cp310-manylinux_2_28_x86_64.whl (40.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 MB 13.1 MB/s eta 0:00:00
# Downloading pyarrow_hotfix-0.6-py3-none-any.whl (7.9 kB)
# Downloading pydot-1.4.2-py2.py3-none-any.whl (21 kB)
# Downloading pymongo-4.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 56.6 MB/s eta 0:00:00
# Downloading redis-5.2.1-py3-none-any.whl (261 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.5/261.5 kB 15.0 MB/s eta 0:00:00
# Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Downloading zstandard-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 93.0 MB/s eta 0:00:00
# Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 19.7 MB/s eta 0:00:00
# Building wheels for collected packages: crcmod, dill, hdfs, docopt
#   Building wheel for crcmod (setup.py) ... done
#   Created wheel for crcmod: filename=crcmod-1.7-cp310-cp310-linux_x86_64.whl size=31407 sha256=53f75de065c655bd531870f2876575cc71f640be6efe59d1c2e45084ecd43551
#   Stored in directory: /root/.cache/pip/wheels/85/4c/07/72215c529bd59d67e3dac29711d7aba1b692f543c808ba9e86
#   Building wheel for dill (setup.py) ... done
#   Created wheel for dill: filename=dill-0.3.1.1-py3-none-any.whl size=78542 sha256=d239f04ff6a134ec8cf6f0e15ce30942b58018694e58515b8767ed2cad916858
#   Stored in directory: /root/.cache/pip/wheels/ea/e2/86/64980d90e297e7bf2ce588c2b96e818f5399c515c4bb8a7e4f
#   Building wheel for hdfs (setup.py) ... done
#   Created wheel for hdfs: filename=hdfs-2.7.3-py3-none-any.whl size=34324 sha256=52a72968257fdf3d955acb40c977222760f1e5221822c77b009335a4a0e204d0
#   Stored in directory: /root/.cache/pip/wheels/e5/8d/b6/99c1c0a3ac5788c866b0ecd3f48b0134a5910e6ed26011800b
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13706 sha256=06a9c54ae7ae9b3048614345dbbb6edd07d013b353bda371ca5b5755a14fb152
#   Stored in directory: /root/.cache/pip/wheels/fc/ab/d4/5da2067ac95b36618c629a5f93f809425700506f72c9732fac
# Successfully built crcmod dill hdfs docopt
# Installing collected packages: sortedcontainers, docopt, crcmod, zstandard, redis, pydot, pyarrow-hotfix, pyarrow, objsize, jsonpickle, grpcio, fasteners, fastavro, dnspython, dill, cloudpickle, pymongo, hdfs, apache-beam
#   Attempting uninstall: pydot
#     Found existing installation: pydot 3.0.3
#     Uninstalling pydot-3.0.3:
#       Successfully uninstalled pydot-3.0.3
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 17.0.0
#     Uninstalling pyarrow-17.0.0:
#       Successfully uninstalled pyarrow-17.0.0
#   Attempting uninstall: jsonpickle
#     Found existing installation: jsonpickle 4.0.1
#     Uninstalling jsonpickle-4.0.1:
#       Successfully uninstalled jsonpickle-4.0.1
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.68.1
#     Uninstalling grpcio-1.68.1:
#       Successfully uninstalled grpcio-1.68.1
#   Attempting uninstall: cloudpickle
#     Found existing installation: cloudpickle 3.1.0
#     Uninstalling cloudpickle-3.1.0:
#       Successfully uninstalled cloudpickle-3.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dask 2024.10.0 requires cloudpickle>=3.0.0, but you have cloudpickle 2.2.1 which is incompatible.
# Successfully installed apache-beam-2.61.0 cloudpickle-2.2.1 crcmod-1.7 dill-0.3.1.1 dnspython-2.7.0 docopt-0.6.2 fastavro-1.10.0 fasteners-0.19 grpcio-1.65.5 hdfs-2.7.3 jsonpickle-3.4.2 objsize-0.7.0 pyarrow-16.1.0 pyarrow-hotfix-0.6 pydot-1.4.2 pymongo-4.10.1 redis-5.2.1 sortedcontainers-2.4.0 zstandard-0.23.0

# %%
import apache_beam as beam
from apache_beam.transforms import window
from apache_beam.options.pipeline_options import PipelineOptions
import datetime
import random

# %% [markdown]
# #beam.WindowInto()
#
# 1.	`beam.WindowInto(beam.window.FixedWindows())` - FixedWindows - Okna o stałej szerokości, np. 10 minut.
# 2.	`beam.WindowInto(beam.window.SlidingWindows())` - SlidingWindows - Okna przesuwające się w czasie, np. okna co 5 minut, które zachodzą na siebie.
# 3.	`beam.WindowInto(beam.window.SessionWindows())` SessionWindows - Okna o zmiennym czasie, tworzone w zależności od przerw w danych (np. jeśli dane nie napływają przez określony czas).
#
#
# Przykład decyzji:
#
# - Jeśli potrzebujesz regularnych raportów -> FixedWindows
# - Jeśli monitorujesz anomalie -> SlidingWindows
# - Jeśli analizujesz zachowania użytkowników -> SessionWindows

# %% [markdown]
# #generate_data

# %%
def generate_data():
    timestamp = datetime.datetime.now()
    for i in range(100):
        event_time = timestamp + datetime.timedelta(minutes=random.randint(0, 20))
        yield {
            'sensor_id': random.randint(1, 5),
            'temperature': random.uniform(20.0, 30.0),
            'timestamp': event_time
        }

# %%
list(generate_data())[:5]
# Out:
# [{'sensor_id': 1,
#   'temperature': 25.479417146221127,
#   'timestamp': datetime.datetime(2025, 1, 7, 14, 36, 53, 91661)},
#  {'sensor_id': 2,
#   'temperature': 24.621569430832658,
#   'timestamp': datetime.datetime(2025, 1, 7, 14, 36, 53, 91661)},
#  {'sensor_id': 3,
#   'temperature': 26.922638491778066,
#   'timestamp': datetime.datetime(2025, 1, 7, 14, 30, 53, 91661)},
#  {'sensor_id': 3,
#   'temperature': 21.55912404598026,
#   'timestamp': datetime.datetime(2025, 1, 7, 14, 32, 53, 91661)},
#  {'sensor_id': 1,
#   'temperature': 29.856935466667483,
#   'timestamp': datetime.datetime(2025, 1, 7, 14, 41, 53, 91661)}]

# %%
# Sposób 1 - bezpośrednie użycie generatora z ograniczeniem
for i, data in enumerate(generate_data()):
    if i < 2:  # Ograniczamy do 5 wierszy
        print(data)
    else:
        break

# Sposób 2 - z użyciem itertools (bardziej elegancki)
from itertools import islice

for data in islice(generate_data(), 2):
    print(data)
# Out:
# {'sensor_id': 5, 'temperature': 24.494212238159026, 'timestamp': datetime.datetime(2025, 1, 7, 14, 45, 26, 846437)}
# {'sensor_id': 1, 'temperature': 28.0515076880288, 'timestamp': datetime.datetime(2025, 1, 7, 14, 33, 26, 846437)}
# {'sensor_id': 1, 'temperature': 25.243036609587932, 'timestamp': datetime.datetime(2025, 1, 7, 14, 36, 26, 848225)}
# {'sensor_id': 4, 'temperature': 23.172863473246018, 'timestamp': datetime.datetime(2025, 1, 7, 14, 29, 26, 848225)}

# %% [markdown]
# #PRZYPADEK 1: FixedWindows

# %%
def generate_data():
    timestamp = datetime.datetime.now()
    for i in range(100):
        event_time = timestamp + datetime.timedelta(minutes=random.randint(0, 20))
        yield {
            'sensor_id': random.randint(1, 5),
            'temperature': random.uniform(20.0, 30.0),
            'timestamp': event_time
        }

def print_element(element, prefix=''):
    print(f"{prefix} > {element}")
    return element

def run():
    options = PipelineOptions()

    with beam.Pipeline(options=options) as p:

        fixed_windows = (
            p
            | "Generuj dane - Fixed" >> beam.Create(list(generate_data()))  # Konwersja do listy
            | "Print dane wejściowe - Fixed" >> beam.Map(lambda x: print_element(x, "Fixed Input"))
            | "Dodaj timestamp - Fixed" >> beam.Map(
                lambda x: beam.window.TimestampedValue(x, x['timestamp'].timestamp()))
            | "Okna 15-min" >> beam.WindowInto(beam.window.FixedWindows(15 * 60))
            | "Przygotuj klucz-wartość" >> beam.Map(lambda x: (x['sensor_id'], x['temperature']))
            | "Grupuj po sensorze - Fixed" >> beam.GroupByKey()
            | "Print po grupowaniu - Fixed" >> beam.Map(lambda x: print_element(x, "Fixed Grouped"))
            | "Oblicz średnią - Fixed" >> beam.Map(
                lambda x: (x[0], sum(x[1]) / len(x[1]))
            )
            | "Print wynik końcowy - Fixed" >> beam.Map(lambda x: print_element(x, "Fixed Result"))
        )

if __name__ == '__main__':
    run()
# Out:
# WARNING:apache_beam.options.pipeline_options:Discarding unparseable args: ['-f', '/root/.local/share/jupyter/runtime/kernel-
 23, 822785)}
# Fixed Input > {'sensor_id': 2, 'temperature': 26.703470827459768, 'timestamp': datetime.datetime(2025, 1, 7, 14, 34, 23, 822785)}
# Fixed Input > {'sensor_id': 2, 'temperature': 24.28214402859237, 'timestamp': datetime.datetime(2025, 1, 7, 14, 42, 23, 822785)}
# Fixed Input > {'sensor_id': 5, 'temperature': 21.200168984852915, 'timestamp': datetime.datetime(2025, 1, 7, 14, 27, 23, 822785)}
# Fixed Input > {'sensor_id': 4, 'temperature': 27.272137952837348, 'timestamp': datetime.datetime(2025, 1, 7, 14, 32, 23, 822785)}
# Fixed Input > {'sensor_id': 2, 'temperature': 21.881979386014645, 'timestamp': datetime.datetime(2025, 1, 7, 14, 44, 23, 822785)}
# Fixed Input > {'sensor_id': 5, 'temperature': 21.80625235850173, 'timestamp': datetime.datetime(2025, 1, 7, 14, 27, 23, 822785)}
# Fixed Input > {'sensor_id': 5, 'temperature': 26.413396647502935, 'timestamp': datetime.datetime(2025, 1, 7, 14, 33, 23, 822785)}
# Fixed Input > {'sensor_id': 5, 'temperature': 20.67072752242844, 'timestamp': datetime.datetime(2025, 1, 7, 14, 43, 23, 822785)}
# Fixed Input > {'sensor_id': 1, 'temperature': 23.888190269772196, 'timestamp': datetime.datetime(2025, 1, 7, 14, 27, 23, 822785)}
# Fixed Input > {'sensor_id': 4, 'temperature': 25.47475107715549, 'timestamp': datetime.datetime(2025, 1, 7, 14, 28, 23, 822785)}
# Fixed Input > {'sensor_id': 5, 'temperature': 22.70016434285523, 'timestamp': datetime.datetime(2025, 1, 7, 14, 38, 23, 822785)}
# Fixed Input > {'sensor_id': 5, 'temperature': 27.118919021175525, 'timestamp': datetime.datetime(2025, 1, 7, 14, 35, 23, 822785)}
# Fixed Input > {'sensor_id': 4, 'temperature': 20.321730800983328, 'timestamp': datetime.datetime(2025, 1, 7, 14, 30, 23, 822785)}
# Fixed Input > {'sensor_id': 5, 'temperature': 29.927553574250375, 'timestamp': datetime.datetime(2025, 1, 7, 14, 35, 23, 822785)}
# Fixed Input > {'sensor_id': 1, 'temperature': 26.10078840932808, 'timestamp': datetime.datetime(2025, 1, 7, 14, 42, 23, 822785)}
# Fixed Input > {'sensor_id': 1, 'temperature': 24.924272033740124, 'timestamp': datetime.datetime(2025, 1, 7, 14, 38, 23, 822785)}
# Fixed Input > {'sensor_id': 5, 'temperature': 26.721735702091127, 'timestamp': datetime.datetime(2025, 1, 7, 14, 36, 23, 822785)}
# Fixed Input > {'sensor_id': 1, 'temperature': 20.629596509155398, 'timestamp': datetime.datetime(2025, 1, 7, 14, 43, 23, 822785)}
# Fixed Input > {'sensor_id': 5, 'temperature': 24.401916918103435, 'timestamp': datetime.datetime(2025, 1, 7, 14, 34, 23, 822785)}
# Fixed Input > {'sensor_id': 2, 'temperature': 21.22972337255735, 'timestamp': datetime.datetime(2025, 1, 7, 14, 40, 23, 822785)}
# Fixed Input > {'sensor_id': 4, 'temperature': 25.650918960560066, 'timestamp': datetime.datetime(2025, 1, 7, 14, 24, 23, 822785)}
# Fixed Input > {'sensor_id': 2, 'temperature': 25.66206495485661, 'timestamp': datetime.datetime(2025, 1, 7, 14, 27, 23, 822785)}
# Fixed Input > {'sensor_id': 4, 'temperature': 20.817698050350412, 'timestamp': datetime.datetime(2025, 1, 7, 14, 39, 23, 822785)}
# Fixed Input > {'sensor_id': 4, 'temperature': 21.729178102380967, 'timestamp': datetime.datetime(2025, 1, 7, 14, 30, 23, 822785)}
# Fixed Input > {'sensor_id': 2, 'temperature': 20.302198985513932, 'timestamp': datetime.datetime(2025, 1, 7, 14, 24, 23, 822785)}
# Fixed Input > {'sensor_id': 4, 'temperature': 25.58606570122261, 'timestamp': datetime.datetime(2025, 1, 7, 14, 35, 23, 822785)}
# Fixed Input > {'sensor_id': 2, 'temperature': 26.39881881811109, 'timestamp': datetime.datetime(2025, 1, 7, 14, 26, 23, 822785)}
# Fixed Input > {'sensor_id': 4, 'temperature': 24.102295911852018, 'timestamp': datetime.datetime(2025, 1, 7, 14, 44, 23, 822785)}
# Fixed Input > {'sensor_id': 5, 'temperature': 24.097664887292044, 'timestamp': datetime.datetime(2025, 1, 7, 14, 29, 23, 822785)}
# Fixed Input > {'sensor_id': 1, 'temperature': 23.115138560115803, 'timestamp': datetime.datetime(2025, 1, 7, 14, 29, 23, 822785)}
# Fixed Input > {'sensor_id': 2, 'temperature': 26.068266826122148, 'timestamp': datetime.datetime(2025, 1, 7, 14, 32, 23, 822785)}
# Fixed Input > {'sensor_id': 1, 'temperature': 29.596402176442545, 'timestamp': datetime.datetime(2025, 1, 7, 14, 40, 23, 822785)}
# Fixed Input > {'sensor_id': 3, 'temperature': 29.816929515880602, 'timestamp': datetime.datetime(2025, 1, 7, 14, 31, 23, 822785)}
# Fixed Input > {'sensor_id': 3, 'temperature': 24.673305263504094, 'timestamp': datetime.datetime(2025, 1, 7, 14, 39, 23, 822785)}
# Fixed Input > {'sensor_id': 5, 'temperature': 28.003151238380127, 'timestamp': datetime.datetime(2025, 1, 7, 14, 30, 23, 822785)}
# Fixed Input > {'sensor_id': 3, 'temperature': 28.23896863275429, 'timestamp': datetime.datetime(2025, 1, 7, 14, 43, 23, 822785)}
# Fixed Input > {'sensor_id': 4, 'temperature': 28.954633330399503, 'timestamp': datetime.datetime(2025, 1, 7, 14, 32, 23, 822785)}
# Fixed Input > {'sensor_id': 1, 'temperature': 29.319883022692927, 'timestamp': datetime.datetime(2025, 1, 7, 14, 27, 23, 822785)}
# Fixed Input > {'sensor_id': 1, 'temperature': 29.832945103652456, 'timestamp': datetime.datetime(2025, 1, 7, 14, 35, 23, 822785)}
# Fixed Input > {'sensor_id': 2, 'temperature': 23.649070551560804, 'timestamp': datetime.datetime(2025, 1, 7, 14, 30, 23, 822785)}
# Fixed Input > {'sensor_id': 4, 'temperature': 24.527376660079824, 'timestamp': datetime.datetime(2025, 1, 7, 14, 26, 23, 822785)}
# Fixed Input > {'sensor_id': 1, 'temperature': 29.253496790015184, 'timestamp': datetime.datetime(2025, 1, 7, 14, 37, 23, 822785)}
# Fixed Grouped > (5, [27.250813444150005, 29.905900718081323, 23.99025900271141, 20.728089867957543, 27.21426778176282, 27.445143566923406, 23.67601389674165, 21.200168984852915, 21.80625235850173, 24.097664887292044])
# Fixed Result > (5, 24.731457450897487)
# Fixed Grouped > (5, [22.375069459300352, 22.58744384705178, 25.375303687465056, 23.262295547508355, 26.533367014162415, 23.966417007695792, 26.413396647502935, 20.67072752242844, 22.70016434285523, 27.118919021175525, 29.927553574250375, 26.721735702091127, 24.401916918103435, 28.003151238380127])
# Fixed Result > (5, 25.004104394997928)
# Fixed Grouped > (4, [26.07122086032122, 20.86915977875521, 25.632138213240143, 20.019848501197586, 21.553752124039885, 28.730624901542853, 24.83060808298015, 27.272137952837348, 20.321730800983328, 20.817698050350412, 21.729178102380967, 25.58606570122261, 24.102295911852018, 28.954633330399503])
# Fixed Result > (4, 24.035078022293085)
# Fixed Grouped > (4, [27.8623726274719, 26.120317244623074, 29.258737553198927, 20.09131915809657, 22.67440327107263, 20.183850251372743, 21.453739846635038, 25.47475107715549, 25.650918960560066, 24.527376660079824])
# Fixed Result > (4, 24.329778665026627)
# Fixed Grouped > (1, [24.806977139008787, 29.253955684875546, 20.179440154016188, 26.65331935356173, 26.111581965776914, 23.58722567628493, 25.03078567889795, 29.002378127973017, 20.252576174974365, 26.120427408138895, 26.10078840932808, 24.924272033740124, 20.629596509155398, 29.596402176442545, 29.832945103652456, 29.253496790015184])
# Fixed Result > (1, 25.70851052411513)
# Fixed Grouped > (1, [20.790673439089634, 29.92596827693384, 20.382717682282816, 23.888190269772196, 23.115138560115803, 29.319883022692927])
# Fixed Result > (1, 24.570428541814536)
# Fixed Grouped > (2, [28.32341681076429, 29.51885103320342, 24.713581812388725, 28.0961777946168, 21.548721467425402, 25.642710789869888, 26.703470827459768, 24.28214402859237, 21.881979386014645, 21.22972337255735, 26.068266826122148, 23.649070551560804])
# Fixed Result > (2, 25.138176225047967)
# Fixed Grouped > (2, [28.3547989125027, 25.66206495485661, 20.302198985513932, 26.39881881811109])
# Fixed Result > (2, 25.17947041774608)
# Fixed Grouped > (3, [21.333187335692205, 26.15468061856456, 25.747406606993938, 27.4364408590746, 22.189727605700938, 21.510099151755586, 26.642586968814527, 29.816929515880602, 24.673305263504094, 28.23896863275429])
# Fixed Result > (3, 25.37433325587353)
# Fixed Grouped > (3, [24.67348161691372, 21.379529289582642, 27.135120949680392, 24.648021404430267])
# Fixed Result > (3, 24.459038315151755)

# %%
"Dodaj timestamp - Fixed" >> beam.Map(lambda x: beam.window.TimestampedValue(x, x['timestamp'].timestamp()))

# Załóżmy, że x to słownik:
x = {
    'sensor_id': 1,
    'temperature': 25.5,
    'timestamp': datetime.datetime(2024, 1, 7, 10, 30, 0)  # przykładowa data
}

# beam.window.TimestampedValue przyjmuje dwa argumenty:
# 1. element - całe dane (x)
# 2. timestamp - unix timestamp w sekundach

# x['timestamp'].timestamp() konwertuje datetime na unix timestamp
# np. datetime(2024, 1, 7, 10, 30, 0).timestamp() -> 1704626400.0

# W rezultacie tworzymy TimestampedValue, który mówi Beam'owi:
# "to zdarzenie wystąpiło dokładnie w tym momencie czasowym"

# %%
"Okna 15-min" >> beam.WindowInto(beam.window.FixedWindows(15 * 60))

# beam.window.FixedWindows(15 * 60) tworzy okna 15-minutowe:
# - 15 * 60 = 900 sekund = 15 minut
# - każde okno jest dokładnie 15 minut długie
# - okna nie nachodzą na siebie

# Przykład podziału na okna:
# Dla danych z timestampami:
# 10:00:00 -> wpada do okna 10:00-10:15
# 10:14:59 -> wpada do okna 10:00-10:15
# 10:15:00 -> wpada do okna 10:15-10:30
# 10:29:59 -> wpada do okna 10:15-10:30

# Wszystkie elementy w jednym oknie będą przetwarzane razem
# np. jeśli mamy 5 odczytów między 10:00 a 10:15,
# zostaną one zagregowane w jednym oknie

# %% [markdown]
# # PRZYPADEK 2: SlidingWindows

# %%
def generate_data():
    timestamp = datetime.datetime.now()
    for i in range(100):
        event_time = timestamp + datetime.timedelta(minutes=random.randint(0, 20))
        yield {
            'sensor_id': random.randint(1, 5),
            'temperature': random.uniform(20.0, 30.0),
            'timestamp': event_time
        }

def print_element(element, prefix=''):
    print(f"{prefix} > {element}")
    return element

def run():
    options = PipelineOptions()

    with beam.Pipeline(options=options) as p:


        sliding_windows = (
            p
            | "Generuj dane - Sliding" >> beam.Create(list(generate_data()))
            | "Print dane wejściowe - Sliding" >> beam.Map(lambda x: print_element(x, "Sliding Input"))
            | "Dodaj timestamp - Sliding" >> beam.Map(
                lambda x: beam.window.TimestampedValue((x['sensor_id'], x['temperature']), x['timestamp'].timestamp()))
            | "Okna przesuwne 30-min" >> beam.WindowInto(
                beam.window.SlidingWindows(30 * 60, 5 * 60))
            | "Grupuj odczyty" >> beam.GroupByKey()
            | "Print po grupowaniu - Sliding" >> beam.Map(lambda x: print_element(x, "Sliding Grouped"))
            | "Wykryj anomalie" >> beam.Map(
                lambda x: {
                    'sensor_id': x[0],
                    'temperatures': list(x[1]),
                    'anomalies': [t for t in x[1] if abs(t - sum(x[1])/len(x[1])) > 2]
                }
            )
            | "Print wynik końcowy - Sliding" >> beam.Map(lambda x: print_element(x, "Sliding Result"))
        )


if __name__ == '__main__':
    run()
# Out:
# WARNING:apache_beam.options.pipeline_options:Discarding unparseable args: ['-f', '/root/.local/share/jupyter/runtime/kernel-b79010ef-563a-45b7-abe1-0015df98b912.json']
# Sliding Input > {'sensor_id': 5, 'temperature': 28.193792550498074, 'timestamp': datetime.datetime(2025, 1, 7, 14, 53, 55, 189604)}
# Sliding Input > {'sensor_id': 4, 'temperature': 27.025469529165452, 'timestamp': datetime.datetime(2025, 1, 7, 15, 9, 55, 189604)}
# Sliding Input > {'sensor_id': 4, 'temperature': 23.724654749472414, 'timestamp': datetime.datetime(2025, 1, 7, 14, 56, 55, 189604)}
# Sliding Input > {'sensor_id': 1, 'temperature': 29.57972965186522, 'timestamp': datetime.datetime(2025, 1, 7, 15, 1, 55, 189604)}
# Sliding Input > {'sensor_id': 4, 'temperature': 23.77232485497126, 'timestamp': datetime.datetime(2025, 1, 7, 14, 58, 55, 189604)}
# Sliding Input > {'sensor_id': 5, 'temperature': 23.619653456893225, 'timestamp': datetime.datetime(2025, 1, 7, 15, 4, 55, 189604)}
# Sliding Input > {'sensor_id': 5, 'temperature': 22.59875867963045, 'timestamp': datetime.datetime(2025, 1, 7, 15, 4, 55, 189604)}
# Sliding Input > {'sensor_id': 2, 'temperature': 25.653146477713396, 'timestamp': datetime.datetime(2025, 1, 7, 15, 2, 55, 189604)}
# Sliding Input > {'sensor_id': 1, 'temperature': 24.166127703324925, 'timestamp': datetime.datetime(2025, 1, 7, 14, 57, 55, 189604)}
# Sliding Input > {'sensor_id': 5, 'temperature': 23.668215030328742, 'timestamp': datetime.datetime(2025, 1, 7, 15, 4, 55, 189604)}
# Sliding Input > {'sensor_id': 2, 'temperature': 20.6703256493584, 'timestamp': datetime.datetime(2025, 1, 7, 15, 4, 55, 189604)}
# Sliding Input > {'sensor_id': 1, 'temperature': 28.047543604058813, 'timestamp': datetime.datetime(2025, 1, 7, 14, 58, 55, 189604)}
# Sliding Input > {'sensor_id': 4, 'temperature': 26.457704304675076, 'timestamp': datetime.datetime(2025, 1, 7, 15, 2, 55, 189604)}
# Sliding Input > {'sensor_id': 1, 'temperature': 28.18638670151499, 'timestamp': datetime.datetime(2025, 1, 7, 14, 57, 55, 189604)}
# Sliding Input > {'sensor_id': 5, 'temperature': 21.212376354978435, 'timestamp': datetime.datetime(2025, 1, 7, 15, 4, 55, 189604)}
# Sliding Input > {'sensor_id': 3, 'temperature':
 'timestamp': datetime.datetime(2025, 1, 7, 14, 51, 55, 189604)}
# Sliding Input > {'sensor_id': 4, 'temperature': 20.834221462769033, 'timestamp': datetime.datetime(2025, 1, 7, 15, 10, 55, 189604)}
# Sliding Input > {'sensor_id': 4, 'temperature': 24.28476227335059, 'timestamp': datetime.datetime(2025, 1, 7, 15, 10, 55, 189604)}
# Sliding Input > {'sensor_id': 4, 'temperature': 25.55747291330733, 'timestamp': datetime.datetime(2025, 1, 7, 14, 54, 55, 189604)}
# Sliding Input > {'sensor_id': 4, 'temperature': 20.270826840533413, 'timestamp': datetime.datetime(2025, 1, 7, 14, 54, 55, 189604)}
# Sliding Input > {'sensor_id': 5, 'temperature': 26.792524907566204, 'timestamp': datetime.datetime(2025, 1, 7, 15, 5, 55, 189604)}
# Sliding Input > {'sensor_id': 1, 'temperature': 28.539606984429923, 'timestamp': datetime.datetime(2025, 1, 7, 15, 4, 55, 189604)}
# Sliding Input > {'sensor_id': 4, 'temperature': 24.02657559479929, 'timestamp': datetime.datetime(2025, 1, 7, 15, 3, 55, 189604)}
# Sliding Input > {'sensor_id': 3, 'temperature': 22.64019586626285, 'timestamp': datetime.datetime(2025, 1, 7, 15, 9, 55, 189604)}
# Sliding Input > {'sensor_id': 2, 'temperature': 24.41017105736048, 'timestamp': datetime.datetime(2025, 1, 7, 14, 52, 55, 189604)}
# Sliding Input > {'sensor_id': 3, 'temperature': 29.010250906999225, 'timestamp': datetime.datetime(2025, 1, 7, 14, 55, 55, 189604)}
# Sliding Input > {'sensor_id': 2, 'temperature': 28.1710207238104, 'timestamp': datetime.datetime(2025, 1, 7, 14, 58, 55, 189604)}
# Sliding Input > {'sensor_id': 3, 'temperature': 21.896532562980905, 'timestamp': datetime.datetime(2025, 1, 7, 14, 51, 55, 189604)}
# Sliding Input > {'sensor_id': 4, 'temperature': 22.19090383081893, 'timestamp': datetime.datetime(2025, 1, 7, 14, 50, 55, 189604)}
# Sliding Input > {'sensor_id': 3, 'temperature': 23.73333416663349, 'timestamp': datetime.datetime(2025, 1, 7, 15, 7, 55, 189604)}
# Sliding Input > {'sensor_id': 1, 'temperature': 20.419694971727523, 'timestamp': datetime.datetime(2025, 1, 7, 15, 0, 55, 189604)}
# Sliding Input > {'sensor_id': 2, 'temperature': 22.149161148448876, 'timestamp': datetime.datetime(2025, 1, 7, 14, 56, 55, 189604)}
# Sliding Input > {'sensor_id': 4, 'temperature': 27.128799044761767, 'timestamp': datetime.datetime(2025, 1, 7, 15, 9, 55, 189604)}
# Sliding Input > {'sensor_id': 1, 'temperature': 27.87569674061195, 'timestamp': datetime.datetime(2025, 1, 7, 14, 59, 55, 189604)}
# Sliding Input > {'sensor_id': 3, 'temperature': 21.884577275378287, 'timestamp': datetime.datetime(2025, 1, 7, 14, 52, 55, 189604)}
# Sliding Input > {'sensor_id': 3, 'temperature': 27.35637503568942, 'timestamp': datetime.datetime(2025, 1, 7, 14, 50, 55, 189604)}
# Sliding Input > {'sensor_id': 5, 'temperature': 23.351263575710128, 'timestamp': datetime.datetime(2025, 1, 7, 15, 9, 55, 189604)}
# Sliding Input > {'sensor_id': 2, 'temperature': 27.795024364905515, 'timestamp': datetime.datetime(2025, 1, 7, 15, 0, 55, 189604)}
# Sliding Input > {'sensor_id': 3, 'temperature': 21.73418439966636, 'timestamp': datetime.datetime(2025, 1, 7, 14, 51, 55, 189604)}
# Sliding Grouped > (5, [28.193792550498074, 23.619653456893225, 22.59875867963045, 23.668215030328742, 21.212376354978435, 28.12966607260041, 27.51551379853821, 23.078434723191833, 27.70649344595904, 27.6825379386452, 22.415698425228648, 23.89080098695792, 26.715826445042552, 20.20200776609642, 27.419915712529388, 26.9090135328802, 26.792524907566204, 23.351263575710128])
# Sliding Result > {'sensor_id': 5, 'temperatures': [28.193792550498074, 23.619653456893225, 22.59875867963045, 23.668215030328742, 21.212376354978435, 28.12966607260041, 27.51551379853821, 23.078434723191833, 27.70649344595904, 27.6825379386452, 22.415698425228648, 23.89080098695792, 26.715826445042552, 20.20200776609642, 27.419915712529388, 26.9090135328802, 26.792524907566204, 23.351263575710128], 'anomalies': [28.193792550498074, 22.59875867963045, 21.212376354978435, 28.12966607260041, 27.51551379853821, 27.70649344595904, 27.6825379386452, 22.415698425228648, 20.20200776609642, 27.419915712529388]}
# Sliding Grouped > (5, [28.193792550498074, 23.619653456893225, 22.59875867963045, 23.668215030328742, 21.212376354978435, 28.12966607260041, 27.51551379853821, 23.078434723191833, 27.70649344595904, 27.6825379386452, 22.415698425228648, 23.89080098695792, 26.715826445042552, 20.20200776609642, 27.419915712529388, 26.9090135328802, 26.792524907566204, 23.351263575710128])
# Sliding Result > {'sensor_id': 5, 'temperatures': [28.193792550498074, 23.619653456893225, 22.59875867963045, 23.668215030328742, 21.212376354978435, 28.12966607260041, 27.51551379853821, 23.078434723191833, 27.70649344595904, 27.6825379386452, 22.415698425228648, 23.89080098695792, 26.715826445042552, 20.20200776609642, 27.419915712529388, 26.9090135328802, 26.792524907566204, 23.351263575710128], 'anomalies': [28.193792550498074, 22.59875867963045, 21.212376354978435, 28.12966607260041, 27.51551379853821, 27.70649344595904, 27.6825379386452, 22.415698425228648, 20.20200776609642, 27.419915712529388]}
# Sliding Grouped > (5, [28.193792550498074, 23.619653456893225, 22.59875867963045, 23.668215030328742, 21.212376354978435, 28.12966607260041, 27.51551379853821, 23.078434723191833, 27.70649344595904, 27.6825379386452, 22.415698425228648, 23.89080098695792, 26.715826445042552, 20.20200776609642, 27.419915712529388, 26.9090135328802, 26.792524907566204, 23.351263575710128])
# Sliding Result > {'sensor_id': 5, 'temperatures': [28.193792550498074, 23.619653456893225, 22.59875867963045, 23.668215030328742, 21.212376354978435, 28.12966607260041, 27.51551379853821, 23.078434723191833, 27.70649344595904, 27.6825379386452, 22.415698425228648, 23.89080098695792, 26.715826445042552, 20.20200776609642, 27.419915712529388, 26.9090135328802, 26.792524907566204, 23.351263575710128], 'anomalies': [28.193792550498074, 22.59875867963045, 21.212376354978435, 28.12966607260041, 27.51551379853821, 27.70649344595904, 27.6825379386452, 22.415698425228648, 20.20200776609642, 27.419915712529388]}
# Sliding Grouped > (5, [28.193792550498074, 23.619653456893225, 22.59875867963045, 23.668215030328742, 21.212376354978435, 28.12966607260041, 27.51551379853821, 27.70649344595904, 27.6825379386452, 22.415698425228648, 23.89080098695792, 26.715826445042552, 20.20200776609642, 27.419915712529388, 26.9090135328802])
# Sliding Result > {'sensor_id': 5, 'temperatures': [28.193792550498074, 23.619653456893225, 22.59875867963045, 23.668215030328742, 21.212376354978435, 28.12966607260041, 27.51551379853821, 27.70649344595904, 27.6825379386452, 22.415698425228648, 23.89080098695792, 26.715826445042552, 20.20200776609642, 27.419915712529388, 26.9090135328802], 'anomalies': [28.193792550498074, 22.59875867963045, 21.212376354978435, 28.12966607260041, 27.51551379853821, 27.70649344595904, 27.6825379386452, 22.415698425228648, 20.20200776609642, 27.419915712529388]}
# Sliding Grouped > (5, [28.193792550498074, 28.12966607260041, 27.51551379853821, 27.6825379386452, 22.415698425228648, 23.89080098695792, 27.419915712529388, 26.9090135328802])
# Sliding Result > {'sensor_id': 5, 'temperatures': [28.193792550498074, 28.12966607260041, 27.51551379853821, 27.6825379386452, 22.415698425228648, 23.89080098695792, 27.419915712529388, 26.9090135328802], 'anomalies': [22.415698425228648, 23.89080098695792]}
# Sliding Grouped > (5, [28.193792550498074, 28.12966607260041, 27.6825379386452, 22.415698425228648, 26.9090135328802])
# Sliding Result > {'sensor_id': 5, 'temperatures': [28.193792550498074, 28.12966607260041, 27.6825379386452, 22.415698425228648, 26.9090135328802], 'anomalies': [22.415698425228648]}
# Sliding Grouped > (5, [23.619653456893225, 22.59875867963045, 23.668215030328742, 21.212376354978435,
.88778866520147, 28.842807788344626, 24.069708634308093, 25.367630478212508, 25.22396353627651, 23.455052305046323, 26.77654665302449, 20.081972068717626, 28.454458337801093, 24.736030085423987, 21.060203425717614, 20.499419192269666, 22.64019586626285, 29.010250906999225, 23.73333416663349])
# Sliding Result > {'sensor_id': 3, 'temperatures': [27.88778866520147, 28.842807788344626, 24.069708634308093, 25.367630478212508, 25.22396353627651, 23.455052305046323, 26.77654665302449, 20.081972068717626, 28.454458337801093, 24.736030085423987, 21.060203425717614, 20.499419192269666, 22.64019586626285, 29.010250906999225, 23.73333416663349], 'anomalies': [27.88778866520147, 28.842807788344626, 20.081972068717626, 28.454458337801093, 21.060203425717614, 20.499419192269666, 22.64019586626285, 29.010250906999225]}
# Sliding Grouped > (3, [20.499419192269666])
# Sliding Result > {'sensor_id': 3, 'temperatures': [20.499419192269666], 'anomalies': []}

# %%
"Dodaj timestamp - Sliding" >> beam.Map(lambda x: beam.window.TimestampedValue((x['sensor_id'], x['temperature']), x['timestamp'].timestamp()))

# Załóżmy przykładowe dane wejściowe:
x = {
    'sensor_id': 1,
    'temperature': 25.5,
    'timestamp': datetime.datetime(2024, 1, 7, 10, 30, 0)
}

# Ta transformacja robi dwie rzeczy naraz:
# 1. Tworzy krotkę z danych: (x['sensor_id'], x['temperature'])
#    Czyli z przykładu: (1, 25.5)

# 2. Dodaje znacznik czasowy poprzez TimestampedValue:
#    - Pierwszy argument to nasza krotka: (1, 25.5)
#    - Drugi to unix timestamp: 1704626400.0

# Różnica w porównaniu do FixedWindows:
# - W Fixed przekazywaliśmy całe 'x'
# - W Sliding przekazujemy tylko potrzebne dane w formie krotki

# %%
"Okna przesuwne 30-min" >> beam.WindowInto(beam.window.SlidingWindows(30 * 60, 5 * 60))

# SlidingWindows przyjmuje dwa argumenty:
# 1. 30 * 60 = 1800 sekund = długość okna (30 minut)
# 2. 5 * 60 = 300 sekund = okres przesunięcia (5 minut)

# Przykład jak działają okna przesuwne:
# Dla danych z timestampem 10:30:00:
# - Wpada do okna 10:15-10:45
# - Wpada do okna 10:20-10:50
# - Wpada do okna 10:25-10:55
# - Wpada do okna 10:30-11:00

# Każde zdarzenie należy do wielu okien jednocześnie!

# %% [markdown]
# # PRZYPADEK 3: SessionWindows

# %%
def generate_data():
    timestamp = datetime.datetime.now()
    for i in range(100):
        event_time = timestamp + datetime.timedelta(minutes=random.randint(0, 20))
        yield {
            'sensor_id': random.randint(1, 5),
            'temperature': random.uniform(20.0, 30.0),
            'timestamp': event_time
        }

def print_element(element, prefix=''):
    print(f"{prefix} > {element}")
    return element

def run():
    options = PipelineOptions()

    with beam.Pipeline(options=options) as p:

        # PRZYPADEK 3: SessionWindows
        session_windows = (
            p
            | "Generuj dane - Session" >> beam.Create(list(generate_data()))
            | "Print dane wejściowe - Session" >> beam.Map(lambda x: print_element(x, "Session Input"))
            | "Przygotuj dane - Session" >> beam.Map(
                lambda x: (x['sensor_id'], x))  # Konwersja do formatu (key, value)
            | "Dodaj timestamp - Session" >> beam.Map(
                lambda x: beam.window.TimestampedValue(x, x[1]['timestamp'].timestamp()))
            | "Sesje 10-min gap" >> beam.WindowInto(
                beam.window.Sessions(10 * 60))
            | "Grupuj po sensorze - Session" >> beam.GroupByKey()
            | "Print po grupowaniu - Session" >> beam.Map(lambda x: print_element(x, "Session Grouped"))
            | "Analizuj sekwencje" >> beam.Map(
                lambda x: {
                    'sensor_id': x[0],
                    'session_duration': (max(d['timestamp'] for d in x[1]) -
                                     min(d['timestamp'] for d in x[1])).total_seconds(),
                    'readings_count': len(list(x[1]))
                }
            )
            | "Print wynik końcowy - Session" >> beam.Map(lambda x: print_element(x, "Session Result"))
        )

if __name__ == '__main__':
    run()
# Out:
# WARNING:apache_beam.options.pipeline_options:Discarding unparseable args: ['-f', '/root/.local/share/jupyter/runtime/kernel-b79010ef-563a-45b7-abe1-0015df98b912.json']
# Session Input > {'sensor_id': 3, 'temperature': 25.57535974908511, 'timestamp': datetime.datetime(2025, 1, 7, 15, 40, 37, 561631)}
# Session Input > {'sensor_id': 1, 'temperature': 25.83268794249436, 'timestamp': datetime.datetime(2025, 1, 7, 15, 34, 37, 561631)}
# Session Input > {'sensor_id': 3, 'temperature': 25.50565501559163, 'timestamp': datetime.datetime(2025, 1, 7, 15, 26, 37, 561631)}
# Session Input > {'sensor_id': 5, 'temperature': 26.023258446135735, 'timestamp': datetime.datetime(2025, 1, 7, 15, 21, 37, 561631)}
# Session Input > {'sensor_id': 2, 'temperature': 25.989437676542998, 'timestamp': datetime.datetime(2025, 1, 7, 15, 23, 37, 561631)}
# Session Input > {'sensor_id': 3, 'temperature': 24.478497359027923, 'timestamp': datetime.datetime(2025, 1, 7, 15, 21, 37, 561631)}
# Session Input > {'sensor_id': 1, 'temperature': 28.029769255472605, 'timestamp': datetime.datetime(2025, 1, 7, 15, 25, 37, 561631)}
# Session Input > {'sensor_id': 2, 'temperature': 28.542792410393453, 'timestamp': datetime.datetime(2025, 1, 7, 15, 37, 37, 561631)}
# Session Input > {'sensor_id': 5, 'temperature': 25.378682369256822, 'timestamp': datetime.datetime(2025, 1, 7, 15, 34, 37, 561631)}
# Session Input > {'sensor_id': 3, 'temperature': 29.001733396894146, 'timestamp': datetime.datetime(2025, 1, 7, 15, 26, 37, 561631)}
# Session Input > {'sensor_id': 5, 'temperature': 27.054611819711333, 'timestamp': datetime.datetime(2025, 1, 7, 15, 29, 37, 561631)}
# Session Input > {'sensor_id': 5, 'temperature': 24.881919908889714, 'timestamp': datetime.datetime(2025, 1, 7, 15, 31, 37, 561631)}
# Session Input > {'sensor_id': 5, 'temperature': 22.713244179180624, 'timestamp': datetime.datetime(2025, 1, 7, 15, 33, 37, 561631)}
# Session Input > {'sensor_id': 3, 'temperature': 28.73829262386173, 'timestamp': datetime.datetime(2025, 1, 7, 15, 30, 37, 561631)}
# Session Input > {'sensor_id': 3, 'temperature': 21.5701747008098, 'timestamp': datetime.datetime(2025, 1, 7, 15, 39, 37, 561631)}
# Session Input > {'sensor_id': 4, 'temperature': 22.451445270902255, 'timestamp': datetime.datetime(2025, 1, 7, 15, 37, 37, 561631)}
# Session Input > {'sensor_id': 4, 'temperature': 28.439332341201652, 'timestamp': datetime.datetime(2025, 1, 7, 15, 25, 37, 561631)}
# Session Input > {'sensor_id': 2, 'temperature': 23.342573939147062, 'timestamp': datetime.datetime(2025, 1, 7, 15, 35, 37, 561631)}
# Session Input > {'sensor_id': 1, 'temperature': 22.323311236286642, 'timestamp': datetime.datetime(2025, 1, 7, 15, 38, 37, 561631)}
# Session Input > {'sensor_id': 1, 'temperature': 25.084211717012955, 'timestamp': datetime.datetime(2025, 1, 7, 15, 37, 37, 561631)}
# Session Input > {'sensor_id': 2, 'temperature': 29.60290228670305, 'timestamp': datetime.datetime(2025, 1, 7, 15, 30, 37, 561631)}
# Session Input > {'sensor_id': 1, 'temperature': 26.464155928581228, 'timestamp': datetime.datetime(2025, 1, 7, 15, 22, 37, 561631)}
# Session Input > {'sensor_id': 3, 'temperature': 21.307448968287755, 'timestamp': datetime.datetime(2025, 1, 7, 15, 26, 37, 561631)}
# Session Input > {'sensor_id': 1, 'temperature': 23.355559809536516, 'timestamp': datetime.datetime(2025, 1, 7, 15, 36, 37, 561631)}
# Session Input > {'sensor_id': 5, 'temperature': 24.227841087625134, 'timestamp': datetime.datetime(2025, 1, 7, 15, 33, 37, 561631)}
# Session Input > {'sensor_id': 3, 'temperature': 28.850174143123564, 'timestamp': datetime.datetime(2025, 1, 7, 15, 24, 37, 561631)}
# Session Input > {'sensor_id': 5, 'temperature': 21.53216081929241, 'timestamp': datetime.datetime(2025, 1, 7, 15, 27, 37, 561631)}
# Session Input > {'sensor_id': 1, 'temperature': 28.517411550786466, 'timestamp': datetime.datetime(2025, 1, 7, 15, 23, 37, 561631)}
# Session Input > {'sensor_id': 4, 'temperature': 22.615466509176596, 'timestamp': datetime.datetime(2025, 1, 7, 15, 27, 37, 561631)}
# Session Input > {'sensor_id': 1, 'temperature': 24.377217554738404, 'timestamp': datetime.datetime(2025, 1, 7, 15, 30, 37, 561631)}
# Session Input > {'sensor_id': 2, 'temperature': 22.861899820233667, 'timestamp': datetime.datetime(2025, 1, 7, 15, 35, 37, 561631)}
# Session Input > {'sensor_id': 1, 'temperature': 21.70806759997761, 'timestamp': datetime.datetime(2025, 1, 7, 15, 29, 37, 561631)}
# Session Input > {'sensor_id': 2, 'temperature': 27.423605309599722, 'timestamp': datetime.datetime(2025, 1, 7, 15, 28, 37, 561631)}
# Session Input > {'sensor_id': 1, 'temperature': 20.48065172042471, 'timestamp': datetime.datetime(2025, 1, 7, 15, 34, 37, 561631)}
# Session Input > {'sensor_id': 1, 'temperature': 20.88412148537671, 'timestamp': datetime.datetime(2025, 1, 7, 15, 33, 37, 561631)}
# Session Input > {'sensor_id': 3, 'temperature': 21.03601515480651, 'timestamp': datetime.datetime(2025, 1, 7, 15, 28, 37, 561631)}
# Session Input > {'sensor_id': 5, 'temperature': 29.63121487533428, 'timestamp': datetime.datetime(2025, 1, 7, 15, 34, 37, 561631)}
# Session Input > {'sensor_id': 1, 'temperature': 26.80283190828613, 'timestamp': datetime.datetime(2025, 1, 7, 15, 32, 37, 561631)}
# Session Input > {'sensor_id': 4, 'temperature': 24.519501750834067, 'timestamp': datetime.datetime(2025, 1, 7, 15, 24, 37, 561631)}
# Session Input > {'sensor_id': 4, 'temperature': 29.099688281288145, 'timestamp': datetime.datetime(2025, 1, 7, 15, 28, 37, 561631)}
# Session Input > {'sensor_id': 1, 'temperature': 28.626387347858298, 'timestamp': datetime.datetime(2025, 1, 7, 15, 32, 37, 561631)}
# Session Input > {'sensor_id': 5, 'temperature': 26.047936051865257, 'timestamp': datetime.datetime(2025, 1, 7, 15, 30, 37, 561631)}
# Session Input > {'sensor_id': 1, 'temperature': 28.677474071754013, 'timestamp': datetime.datetime(2025, 1, 7, 15, 32, 37, 561631)}
# Session Input > {'sensor_id': 2, 'temperature': 20.405711773610097, 'timestamp': datetime.datetime(2025, 1, 7, 15, 29, 37, 561631)}
# Session Input > {'sensor_id': 1, 'temperature': 20.241163228025567, 'timestamp': datetime.datetime(2025, 1, 7, 15, 26, 37, 561631)}
# Session Input > {'sensor_id': 4, 'temperature': 25.804026366170362, 'timestamp': datetime.datetime(2025, 1, 7, 15, 29, 37, 561631)}
# Session Input > {'sensor_id': 2, 'temperature': 29.283989050263024, 'timestamp': datetime.datetime(2025, 1, 7, 15, 28, 37, 561631)}
# Session Input > {'sensor_id': 2, 'temperature': 24.589686534611744, 'timestamp': datetime.datetime(2025, 1, 7, 15, 37, 37, 561631)}
# Session Input > {'sensor_id': 1, 'temperature': 24.277511276479483, 'timestamp': datetime.datetime(2025, 1, 7, 15, 26, 37, 561631)}
# Session Input > {'sensor_id': 3, 'temperature': 26.816914618009623, 'timestamp': datetime.datetime(2025, 1, 7, 15, 34, 37, 561631)}
# Session Input > {'sensor_id': 3, 'temperature': 29.301696157405296, 'timestamp': datetime.datetime(2025, 1, 7, 15, 33, 37, 561631)}
# Session Input > {'sensor_id': 5, 'temperature': 21.626197723272547, 'timestamp': datetime.datetime(2025, 1, 7, 15, 22, 37, 561631)}
# Session Input > {'sensor_id': 4, 'temperature': 22.61322527482833, 'timestamp': datetime.datetime(2025, 1, 7, 15, 32, 37, 561631)}
# Session Input > {'sensor_id': 1, 'temperature': 20.689362593303233, 'timestamp': datetime.datetime(2025, 1, 7, 15, 23, 37, 561631)}
# Session Input > {'sensor_id': 2, 'temperature': 29.641747171467756, 'timestamp': datetime.datetime(2025, 1, 7, 15, 24, 37, 561631)}
# Session Input > {'sensor_id': 1, 'temperature': 26.753980305801417, 'timestamp': datetime.datetime(2025, 1, 7, 15, 29, 37, 561631)}
# Session Input > {'sensor_id': 5, 'temperature': 29.444462660390656, 'timestamp': datetime.datetime(2025, 1, 7, 15, 33, 37, 561631)}
# Session Input > {'sensor_id': 4, 'temperature': 26.942020745208616, 'timestamp': datetime.datetime(2025, 1, 7, 15, 22, 37, 561631)}
# Session Input > {'sensor_id': 2, 'temperature': 28.741906636765492, 'timestamp': datetime.datetime(2025, 1, 7, 15, 40, 37, 561631)}
# Session Input > {'sensor_id': 4, 'temperature': 21.09158332167958, 'timestamp': datetime.datetime(2025, 1, 7, 15, 35, 37, 561631)}
# Session Input > {'sensor_id': 3, 'temperature': 29.89510798138963, 'timestamp': datetime.datetime(2025, 1, 7, 15, 31, 37, 561631)}
# Session Input > {'sensor_id': 3, 'temperature': 22.2846690411519, 'timestamp': datetime.datetime(2025, 1, 7, 15, 21, 37, 561631)}
# Session Input > {'sensor_id': 3, 'temperature': 28.36502762716261, 'timestamp': datetime.datetime(2025, 1, 7, 15, 30, 37, 561631)}
# Session Input > {'sensor_id': 3, 'temperature': 20.186961404607104, 'timestamp': datetime.datetime(2025, 1, 7, 15, 28, 37, 561631)}
# Session Input > {'sensor_id': 4, 'temperature': 21.334558373122395, 'timestamp': datetime.datetime(2025, 1, 7, 15, 29, 37, 561631)}
# Session Input > {'sensor_id': 3, 'temperature': 25.88094813852203, 'timestamp': datetime.datetime(2025, 1, 7, 15, 25, 37, 561631)}
# Session Input > {'sensor_id': 1, 'temperature': 28.77010071262381, 'timestamp': datetime.datetime(2025, 1, 7, 15, 26, 37, 561631)}
# Session Input > {'sensor_id': 3, 'temperature': 29.825389075723606, 'timestamp': datetime.datetime(2025, 1, 7, 15, 30, 37, 561631)}
# Session Input > {'sensor_id': 3, 'temperature': 25.571496092951733, 'timestamp': datetime.datetime(2025, 1, 7, 15, 33, 37, 561631)}
# Session Input > {'sensor_id': 2, 'temperature': 27.356955882851754, 'timestamp': datetime.datetime(2025, 1, 7, 15, 26, 37, 561631)}
# Session Input > {'sensor_id': 3, 'temperature': 20.01421470713541, 'timestamp': datetime.datetime(2025, 1, 7, 15, 20, 37, 561631)}
# Session Input > {'sensor_id': 2, 'temperature': 28.495466490994797, 'timestamp': datetime.datetime(2025, 1, 7, 15, 38, 37, 561631)}
# Session Input > {'sensor_id': 3, 'temperature': 24.935821064942544, 'timestamp': datetime.datetime(2025, 1, 7, 15, 37, 37, 561631)}
# Session Input > {'sensor_id': 5, 'temperature': 28.700699335957868, 'timestamp': datetime.datetime(2025, 1, 7, 15, 39, 37, 561631)}
# Session Input > {'sensor_id': 4, 'temperature': 22.477593736537408, 'timestamp': datetime.datetime(2025, 1, 7, 15, 26, 37, 561631)}
# Session Input > {'sensor_id': 4, 'temperature': 25.102015000532212, 'timestamp': datetime.datetime(2025, 1, 7, 15, 24, 37, 561631)}
# Session Input > {'sensor_id': 2, 'temperature': 29.365179755768697, 'timestamp': datetime.datetime(2025, 1, 7, 15, 37, 37, 561631)}
# Session Input > {'sensor_id': 4, 'temperature': 23.394938168884643, 'timestamp': datetime.datetime(2025, 1, 7, 15, 40, 37, 561631)}
# Session Input > {'sensor_id': 3, 'temperature': 27.70476480300255, 'timestamp': datetime.datetime(2025, 1, 7, 15, 25, 37, 561631)}
# Session Input > {'sensor_id': 1, 'temperature': 24.995582716659538, 'timestamp': datetime.datetime(2025, 1, 7, 15, 35, 37, 561631)}
# Session Input > {'sensor_id': 1, 'temperature': 25.314585950236197, 'timestamp': datetime.datetime(2025, 1, 7, 15, 23, 37, 561631)}
# Session Input > {'sensor_id': 2, 'temperature': 26.964516492460927, 'timestamp': datetime.datetime(2025, 1, 7, 15, 21, 37, 561631)}
# Session Input > {'sensor_id': 3, 'temperature': 25.25831409287091, 'timestamp': datetime.datetime(2025, 1, 7, 15, 24, 37, 561631)}
# Session Input > {'sensor_id': 2, 'temperature': 22.04373555144509, 'timestamp': datetime.datetime(2025, 1, 7, 15, 33, 37, 561631)}
# Session Input > {'sensor_id': 5, 'temperature': 25.065908730937885, 'timestamp': datetime.datetime(2025, 1, 7, 15, 35, 37, 561631)}
# Session Input > {'sensor_id': 4, 'temperature': 23.322355956614555, 'timestamp': datetime.datetime(2025, 1, 7, 15, 32, 37, 561631)}
# Session Input > {'sensor_id': 4, 'temperature': 26.04320662004064, 'timestamp': datetime.datetime(2025, 1, 7, 15, 37, 37, 561631)}
# Session Input > {'sensor_id': 2, 'temperature': 29.60345577683747, 'timestamp': datetime.datetime(2025, 1, 7, 15, 39, 37, 561631)}
# Session Input > {'sensor_id': 3, 'temperature': 26.826167177382892, 'timestamp': datetime.datetime(2025, 1, 7, 15, 24, 37, 561631)}
# Session Input > {'sensor_id': 4, 'temperature': 21.442054588138923, 'timestamp': datetime.datetime(2025, 1, 7, 15, 21, 37, 561631)}
# Session Input > {'sensor_id': 1, 'temperature': 27.53506566185314, 'timestamp': datetime.datetime(2025, 1, 7, 15, 26, 37, 561631)}
# Session Input > {'sensor_id': 1, 'temperature': 24.04560438189447, 'timestamp': datetime.datetime(2025, 1, 7, 15, 37, 37, 561631)}
# Session Input > {'sensor_id': 2, 'temperature': 22.957320069540508, 'timestamp': datetime.datetime(2025, 1, 7, 15, 39, 37, 561631)}
# Session Input > {'sensor_id': 3, 'temperature': 28.74684849999621, 'timestamp': datetime.datetime(2025, 1, 7, 15, 33, 37, 561631)}
# Session Input > {'sensor_id': 3, 'temperature': 20.129496168553537, 'timestamp': datetime.datetime(2025, 1, 7, 15, 33, 37, 561631)}
# Session Input > {'sensor_id': 3, 'temperature': 22.16146831289765, 'timestamp': datetime.datetime(2025, 1, 7, 15, 36, 37, 561631)}
# Session Input > {'sensor_id': 1, 'temperature': 23.584877838225566, 'timestamp': datetime.datetime(2025, 1, 7, 15, 32, 37, 561631)}
# Session Input > {'sensor_id': 4, 'temperature': 22.879229815420953, 'timestamp': datetime.datetime(2025, 1, 7, 15, 26, 37, 561631)}
# Session Input > {'sensor_id': 3, 'temperature': 23.28230708254731, 'timestamp': datetime.datetime(2025, 1, 7, 15, 40, 37, 561631)}
# Session Input > {'sensor_id': 4, 'temperature': 27.397373184002312, 'timestamp': datetime.datetime(2025, 1, 7, 15, 30, 37, 561631)}
# Session Grouped > (3, [{'sensor_id': 3, 'temperature': 25.57535974908511, 'timestamp': datetime.datetime(2025, 1, 7, 15, 40, 37, 561631)}, {'sensor_id': 3, 'temperature': 23.28230708254731, 'timestamp': datetime.datetime(2025, 1, 7, 15, 40, 37, 561631)}, {'sensor_id': 3, 'temperature': 25.50565501559163, 'timestamp': datetime.datetime(2025, 1, 7, 15, 26, 37, 561631)}, {'sensor_id': 3, 'temperature': 29.001733396894146, 'timestamp': datetime.datetime(2025, 1, 7, 15, 26, 37, 561631)}, {'sensor_id': 3, 'temperature': 21.307448968287755, 'timestamp': datetime.datetime(2025, 1, 7, 15, 26, 37, 561631)}, {'sensor_id': 3, 'temperature': 24.478497359027923, 'timestamp': datetime.datetime(2025, 1, 7, 15, 21, 37, 561631)}, {'sensor_id': 3, 'temperature': 22.2846690411519, 'timestamp': datetime.datetime(2025, 1, 7, 15, 21, 37, 561631)}, {'sensor_id': 3, 'temperature': 28.73829262386173, 'timestamp': datetime.datetime(2025, 1, 7, 15, 30, 37, 561631)}, {'sensor_id': 3, 'temperature': 28.36502762716261, 'timestamp': datetime.datetime(2025, 1, 7, 15, 30, 37, 561631)}, {'sensor_id': 3, 'temperature': 29.825389075723606, 'timestamp': datetime.datetime(2025, 1, 7, 15, 30, 37, 561631)}, {'sensor_id': 3, 'temperature': 21.5701747008098, 'timestamp': datetime.datetime(2025, 1, 7, 15, 39, 37, 561631)}, {'sensor_id': 3, 'temperature': 28.850174143123564, 'timestamp': datetime.datetime(2025, 1, 7, 15, 24, 37, 561631)}, {'sensor_id': 3, 'temperature': 25.25831409287091, 'timestamp': datetime.datetime(2025, 1, 7, 15, 24, 37, 561631)}, {'sensor_id': 3, 'temperature': 26.826167177382892, 'timestamp': datetime.datetime(2025, 1, 7, 15, 24, 37, 561631)}, {'sensor_id': 3, 'temperature': 21.03601515480651, 'timestamp': datetime.datetime(2025, 1, 7, 15, 28, 37, 561631)}, {'sensor_id': 3, 'temperature': 20.186961404607104, 'timestamp': datetime.datetime(2025, 1, 7, 15, 28, 37, 561631)}, {'sensor_id': 3, 'temperature': 26.816914618009623, 'timestamp': datetime.datetime(2025, 1, 7, 15, 34, 37, 561631)}, {'sensor_id': 3, 'temperature': 29.301696157405296, 'timestamp': datetime.datetime(2025, 1, 7, 15, 33, 37, 561631)}, {'sensor_id': 3, 'temperature': 25.571496092951733, 'timestamp': datetime.datetime(2025, 1, 7, 15, 33, 37, 561631)}, {'sensor_id': 3, 'temperature': 28.74684849999621, 'timestamp': datetime.datetime(2025, 1, 7, 15, 33, 37, 561631)}, {'sensor_id': 3, 'temperature': 20.129496168553537, 'timestamp': datetime.datetime(2025, 1, 7, 15, 33, 37, 561631)}, {'sensor_id': 3, 'temperature': 29.89510798138963, 'timestamp': datetime.datetime(2025, 1, 7, 15, 31, 37, 561631)}, {'sensor_id': 3, 'temperature': 25.88094813852203, 'timestamp': datetime.datetime(2025, 1, 7, 15, 25, 37, 561631)}, {'sensor_id': 3, 'temperature': 27.70476480300255, 'timestamp': datetime.datetime(2025, 1, 7, 15, 25, 37, 561631)}, {'sensor_id': 3, 'temperature': 20.01421470713541, 'timestamp': datetime.datetime(2025, 1, 7, 15, 20, 37, 561631)}, {'sensor_id': 3, 'temperature': 24.935821064942544, 'timestamp': datetime.datetime(2025, 1, 7, 15, 37, 37, 561631)}, {'sensor_id': 3, 'temperature': 22.16146831289765, 'timestamp': datetime.datetime(2025, 1, 7, 15, 36, 37, 561631)}])
# Session Result > {'sensor_id': 3, 'session_duration': 1200.0, 'readings_count': 27}
# Session Grouped > (1, [{'sensor_id': 1, 'temperature': 25.83268794249436, 'timestamp': datetime.datetime(2025, 1, 7, 15, 34, 37, 561631)}, {'sensor_id': 1, 'temperature': 20.48065172042471, 'timestamp': datetime.datetime(2025, 1, 7, 15, 34, 37, 561631)}, {'sensor_id': 1, 'temperature': 28.029769255472605, 'timestamp': datetime.datetime(2025, 1, 7, 15, 25, 37, 561631)}, {'sensor_id': 1, 'temperature': 22.323311236286642, 'timestamp': datetime.datetime(2025, 1, 7, 15, 38, 37, 561631)}, {'sensor_id': 1, 'temperature': 25.084211717012955, 'timestamp': datetime.datetime(2025, 1, 7, 15, 37, 37, 561631)}, {'sensor_id': 1, 'temperature': 24.04560438189447, 'timestamp': datetime.datetime(2025, 1, 7, 15, 37, 37, 561631)}, {'sensor_id': 1, 'temperature': 26.464155928581228, 'timestamp': datetime.datetime(2025, 1, 7, 15, 22, 37, 561631)}, {'sensor_id': 1, 'temperature': 23.355559809536516, 'timestamp': datetime.datetime(2025, 1, 7, 15, 36, 37, 561631)}, {'sensor_id': 1, 'temperature': 28.517411550786466, 'timestamp': datetime.datetime(2025, 1, 7, 15, 23, 37, 561631)}, {'sensor_id': 1, 'temperature': 20.689362593303233, 'timestamp': datetime.datetime(2025, 1, 7, 15, 23, 37, 561631)}, {'sensor_id': 1, 'temperature': 25.314585950236197, 'timestamp': datetime.datetime(2025, 1, 7, 15, 23, 37, 561631)}, {'sensor_id': 1, 'temperature': 24.377217554738404, 'timestamp': datetime.datetime(2025, 1, 7, 15, 30, 37, 561631)}, {'sensor_id': 1, 'temperature': 21.70806759997761, 'timestamp': datetime.datetime(2025, 1, 7, 15, 29, 37, 561631)}, {'sensor_id': 1, 'temperature': 26.753980305801417, 'timestamp': datetime.datetime(2025, 1, 7, 15, 29, 37, 561631)}, {'sensor_id': 1, 'temperature': 20.88412148537671, 'timestamp': datetime.datetime(2025, 1, 7, 15, 33, 37, 561631)}, {'sensor_id': 1, 'temperature': 26.80283190828613, 'timestamp': datetime.datetime(2025, 1, 7, 15, 32, 37, 561631)}, {'sensor_id': 1, 'temperature': 28.626387347858298, 'timestamp': datetime.datetime(2025, 1, 7, 15, 32, 37, 561631)}, {'sensor_id': 1, 'temperature': 28.677474071754013, 'timestamp': datetime.datetime(2025, 1, 7, 15, 32, 37, 561631)}, {'sensor_id': 1, 'temperature': 23.584877838225566, 'timestamp': datetime.datetime(2025, 1, 7, 15, 32, 37, 561631)}, {'sensor_id': 1, 'temperature': 20.241163228025567, 'timestamp': datetime.datetime(2025, 1, 7, 15, 26, 37, 561631)}, {'sensor_id': 1, 'temperature': 24.277511276479483, 'timestamp': datetime.datetime(2025, 1, 7, 15, 26, 37, 561631)}, {'sensor_id': 1, 'temperature': 28.77010071262381, 'timestamp': datetime.datetime(2025, 1, 7, 15, 26, 37, 561631)}, {'sensor_id': 1, 'temperature': 27.53506566185314, 'timestamp': datetime.datetime(2025, 1, 7, 15, 26, 37, 561631)}, {'sensor_id': 1, 'temperature': 24.995582716659538, 'timestamp': datetime.datetime(2025, 1, 7, 15, 35, 37, 561631)}])
# Session Result > {'sensor_id': 1, 'session_duration': 960.0, 'readings_count': 24}
# Session Grouped > (5, [{'sensor_id': 5, 'temperature': 26.023258446135735, 'timestamp': datetime.datetime(2025, 1, 7, 15, 21, 37, 561631)}, {'sensor_id': 5, 'temperature': 25.378682369256822, 'timestamp': datetime.datetime(2025, 1, 7, 15, 34, 37, 561631)}, {'sensor_id': 5, 'temperature': 29.63121487533428, 'timestamp': datetime.datetime(2025, 1, 7, 15, 34, 37, 561631)}, {'sensor_id': 5, 'temperature': 27.054611819711333, 'timestamp': datetime.datetime(2025, 1, 7, 15, 29, 37, 561631)}, {'sensor_id': 5, 'temperature': 24.881919908889714, 'timestamp': datetime.datetime(2025, 1, 7, 15, 31, 37, 561631)}, {'sensor_id': 5, 'temperature': 22.713244179180624, 'timestamp': datetime.datetime(2025, 1, 7, 15, 33, 37, 561631)}, {'sensor_id': 5, 'temperature': 24.227841087625134, 'timestamp': datetime.datetime(2025, 1, 7, 15, 33, 37, 561631)}, {'sensor_id': 5, 'temperature': 29.444462660390656, 'timestamp': datetime.datetime(2025, 1, 7, 15, 33, 37, 561631)}, {'sensor_id': 5, 'temperature': 21.53216081929241, 'timestamp': datetime.datetime(2025, 1, 7, 15, 27, 37, 561631)}, {'sensor_id': 5, 'temperature': 26.047936051865257, 'timestamp': datetime.datetime(2025, 1, 7, 15, 30, 37, 561631)}, {'sensor_id': 5, 'temperature': 21.626197723272547, 'timestamp': datetime.datetime(2025, 1, 7, 15, 22, 37, 561631)}, {'sensor_id': 5, 'temperature': 28.700699335957868, 'timestamp': datetime.datetime(2025, 1, 7, 15, 39, 37, 561631)}, {'sensor_id': 5, 'temperature': 25.065908730937885, 'timestamp': datetime.datetime(2025, 1, 7, 15, 35, 37, 561631)}])
# Session Result > {'sensor_id': 5, 'session_duration': 1080.0, 'readings_count': 13}
# Session Grouped > (2, [{'sensor_id': 2, 'temperature': 25.989437676542998, 'timestamp': datetime.datetime(2025, 1, 7, 15, 23, 37, 561631)}, {'sensor_id': 2, 'temperature': 28.542792410393453, 'timestamp': datetime.datetime(2025, 1, 7, 15, 37, 37, 561631)}, {'sensor_id': 2, 'temperature': 24.589686534611744, 'timestamp': datetime.datetime(2025, 1, 7, 15, 37, 37, 561631)}, {'sensor_id': 2, 'temperature': 29.365179755768697, 'timestamp': datetime.datetime(2025, 1, 7, 15, 37, 37, 561631)}, {'sensor_id': 2, 'temperature': 23.342573939147062, 'timestamp': datetime.datetime(2025, 1, 7, 15, 35, 37, 561631)}, {'sensor_id': 2, 'temperature': 22.861899820233667, 'timestamp': datetime.datetime(2025, 1, 7, 15, 35, 37, 561631)}, {'sensor_id': 2, 'temperature': 29.60290228670305, 'timestamp': datetime.datetime(2025, 1, 7, 15, 30, 37, 561631)}, {'sensor_id': 2, 'temperature': 27.423605309599722, 'timestamp': datetime.datetime(2025, 1, 7, 15, 28, 37, 561631)}, {'sensor_id': 2, 'temperature': 29.283989050263024, 'timestamp': datetime.datetime(2025, 1, 7, 15, 28, 37, 561631)}, {'sensor_id': 2, 'temperature': 20.405711773610097, 'timestamp': datetime.datetime(2025, 1, 7, 15, 29, 37, 561631)}, {'sensor_id': 2, 'temperature': 29.641747171467756, 'timestamp': datetime.datetime(2025, 1, 7, 15, 24, 37, 561631)}, {'sensor_id': 2, 'temperature': 28.741906636765492, 'timestamp': datetime.datetime(2025, 1, 7, 15, 40, 37, 561631)}, {'sensor_id': 2, 'temperature': 27.356955882851754, 'timestamp': datetime.datetime(2025, 1, 7, 15, 26, 37, 561631)}, {'sensor_id': 2, 'temperature': 28.495466490994797, 'timestamp': datetime.datetime(2025, 1, 7, 15, 38, 37, 561631)}, {'sensor_id': 2, 'temperature': 26.964516492460927, 'timestamp': datetime.datetime(2025, 1, 7, 15, 21, 37, 561631)}, {'sensor_id': 2, 'temperature': 22.04373555144509, 'timestamp': datetime.datetime(2025, 1, 7, 15, 33, 37, 561631)}, {'sensor_id': 2, 'temperature': 29.60345577683747, 'timestamp': datetime.datetime(2025, 1, 7, 15, 39, 37, 561631)}, {'sensor_id': 2, 'temperature': 22.957320069540508, 'timestamp': datetime.datetime(2025, 1, 7, 15, 39, 37, 561631)}])
# Session Result > {'sensor_id': 2, 'session_duration': 1140.0, 'readings_count': 18}
# Session Grouped > (4, [{'sensor_id': 4, 'temperature': 22.451445270902255, 'timestamp': datetime.datetime(2025, 1, 7, 15, 37, 37, 561631)}, {'sensor_id': 4, 'temperature': 26.04320662004064, 'timestamp': datetime.datetime(2025, 1, 7, 15, 37, 37, 561631)}, {'sensor_id': 4, 'temperature': 28.439332341201652, 'timestamp': datetime.datetime(2025, 1, 7, 15, 25, 37, 561631)}, {'sensor_id': 4, 'temperature': 22.615466509176596, 'timestamp': datetime.datetime(2025, 1, 7, 15, 27, 37, 561631)}, {'sensor_id': 4, 'temperature': 24.519501750834067, 'timestamp': datetime.datetime(2025, 1, 7, 15, 24, 37, 561631)}, {'sensor_id': 4, 'temperature': 25.102015000532212, 'timestamp': datetime.datetime(2025, 1, 7, 15, 24, 37, 561631)}, {'sensor_id': 4, 'temperature': 29.099688281288145, 'timestamp': datetime.datetime(2025, 1, 7, 15, 28, 37, 561631)}, {'sensor_id': 4, 'temperature': 25.804026366170362, 'timestamp': datetime.datetime(2025, 1, 7, 15, 29, 37, 561631)}, {'sensor_id': 4, 'temperature': 21.334558373122395, 'timestamp': datetime.datetime(2025, 1, 7, 15, 29, 37, 561631)}, {'sensor_id': 4, 'temperature': 22.61322527482833, 'timestamp': datetime.datetime(2025, 1, 7, 15, 32, 37, 561631)}, {'sensor_id': 4, 'temperature': 23.322355956614555, 'timestamp': datetime.datetime(2025, 1, 7, 15, 32, 37, 561631)}, {'sensor_id': 4, 'temperature': 26.942020745208616, 'timestamp': datetime.datetime(2025, 1, 7, 15, 22, 37, 561631)}, {'sensor_id': 4, 'temperature': 21.09158332167958, 'timestamp': datetime.datetime(2025, 1, 7, 15, 35, 37, 561631)}, {'sensor_id': 4, 'temperature': 22.477593736537408, 'timestamp': datetime.datetime(2025, 1, 7, 15, 26, 37, 561631)}, {'sensor_id': 4, 'temperature': 22.879229815420953, 'timestamp': datetime.datetime(2025, 1, 7, 15, 26, 37, 561631)}, {'sensor_id': 4, 'temperature': 23.394938168884643, 'timestamp': datetime.datetime(2025, 1, 7, 15, 40, 37, 561631)}, {'sensor_id': 4, 'temperature': 21.442054588138923, 'timestamp': datetime.datetime(2025, 1, 7, 15, 21, 37, 561631)}, {'sensor_id': 4, 'temperature': 27.397373184002312, 'timestamp': datetime.datetime(2025, 1, 7, 15, 30, 37, 561631)}])
# Session Result > {'sensor_id': 4, 'session_duration': 1140.0, 'readings_count': 18}

# %%
"Dodaj timestamp - Session" >> beam.Map(
    lambda x: beam.window.TimestampedValue(x, x[1]['timestamp'].timestamp()))

# Cel: Dodanie znacznika czasu do elementów przetwarzanych w potoku.
# beam.Map: Transformacja, która stosuje funkcję (tutaj lambda) do każdego elementu x w PCollection.
# lambda x: beam.window.TimestampedValue(...):
# Tworzymy obiekt TimestampedValue, który opakowuje element x wraz ze znacznikiem czasu.
# x[1]['timestamp'] zakłada, że x jest krotką lub strukturą podobną do słownika, gdzie drugi element (x[1]) zawiera klucz 'timestamp'.
# .timestamp() konwertuje znacznik czasu (np. datetime) na liczbę sekund od epoki Unix (czas uniksowy).
# Efekt: Każdy element w PCollection ma teraz przypisany znacznik czasu, który Apache Beam użyje do okien czasowych.

# %%
"Sesje 10-min gap" >> beam.WindowInto(
    beam.window.Sessions(10 * 60))

# Cel: Grupowanie danych w okna sesji na podstawie przypisanych wcześniej znaczników czasu.
# beam.WindowInto: Ustawia strategię okienkowania dla PCollection. W tym przypadku korzystamy z okien sesji.
# beam.window.Sessions(10 * 60): Tworzy okna sesji z luką czasową wynoszącą 10 minut (wyrażone w sekundach: 10 * 60).
# Okna sesji: Dzielą dane na dynamiczne przedziały czasowe, które kończą się, jeśli przez określoną lukę (tutaj 10 minut) nie pojawią się nowe dane.
# Efekt:
# Elementy z podobnymi znacznikami czasu, które są blisko siebie (w granicach 10 minut), zostaną zgrupowane w to samo okno sesji.
# Jeżeli między zdarzeniami wystąpi luka większa niż 10 minut, zostanie utworzone nowe okno sesji.
